# %% [markdown]
# # Practical 06 - Set Operations and Relations

# %% [markdown]
# ## Setup

# %%
# specify your student id and your name, then press Shift+Enter

student_id = 'W00000000'
student_name = 'Firstname Surname'

# %%
# setup magic, do not edit this! Just press Shift+Enter

# %matplotlib inline
import urllib.request

try:
    content = urllib.request.urlretrieve ("http://kmurphy.bitbucket.io/modules/Discrete_Mathematics/files/setup_practical_magic.py")
    exec(open(content[0]).read())
except:
    from setup_practical_magic import *
setup_practical(locals())
# Out:
# <script>alert('Make sure to specify your student ID and your name in the Setup section of this notebook.');</script>
# <style>
#
#
#
# /* counting headers and my styling */
#
# .navbar-collapse.collapse {
# display: block!important;
# }
#
# .navbar-nav>li, .navbar-nav {
# float: left !important;
# }
#
# .navbar-nav.navbar-right:last-child {
# margin-right: -15px !important;
# }
#
# .navbar-right {
# float: right!important;
# }
#
# #notebook_name {
#     font-weight: 600;
# }
#
# h1 {
# 	text-align: center;
# 	background-color: rgba(0,255,1,0.15);
# 	border-bottom: 1px solid #cccccc;
# 	counter-reset: h2counter;
# }
#
# h2 {
# 	text-align: center;
# 	width: 75%;
# 	margin-left: 25%;
# 	background-color: rgba(255,255,1,0.15);
# 	border-bottom: 1px solid #cccccc;
# 	counter-reset: h3counter;
# }
# h2:before {
# 	counter-increment: h2counter;
# }
#
# h3 {
# 	border-bottom: 1px solid #cccccc;
# }
# h3:before {
# 	counter-increment: h3counter;
# }
#
# h4 {
# ...

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this practical we will
#
#   * Determine relationship between sets (subset, etc.)
#   * Demonstrate set operations (union, intersection, etc.)
#   * Prove set identities using membership tables.
#
#
# ### Mathematics Concepts
#
#  * Set relations: subset \\(\subseteq\\), superset \\(\supseteq\\)
#  * Set operations: intersection \\(\cap\\), union \\(\cup\\),  set difference \\(\setminus\\), symmetric difference \\(\oplus\\)
#
#
#
# ### Python Syntax/Modules/Commands
#
#  * Set relations: subset  \\(A \subseteq B\\)
#
# ~~~.python
#     A.issubset(B)
# ~~~
#
#  * Set relations: subset  \\(A \supseteq B\\)
#
# ~~~.python
#     A.issuperset(B)
# ~~~
#
#  * Set operations: intersection \\(\cap\\)
#
# ~~~.python
#     C = A.intersection(B)
# ~~~
#
#
#  * Set operations: union \\(\cup\\)
#
# ~~~.python
#     C = A.union(B)
# ~~~
#
#  * Set operations: set difference \\(A\setminus B\\)
#
# ~~~.python
#     C = A.difference(B)
# ~~~
#
#  * Set operations: Cartesian product \\(A\times B\\)
#
# ~~~.python
#     C = { (a,b) for a in A for b in B }
# ~~~
#
#  * Set operations: Relation, for example "less than"
#
# ~~~.python
#     C = { (a,b) for a in A for b in B if a<b}
# ~~~

# %% [markdown]
# ## Set Operations

# %% [markdown]
# **Question 1**
#
# Write code to
#
#  * Create set \\(A\\) containg natural numbers up to but not including 20
#  * Create set \\(B\\) containg even natural numbers up to but not including 10
#  * Output set \\(A\setminus B\\)
#
# Hint: use __range()__ function to generate sets

# %%
# Question 1

# %% [markdown]
# **Question 2**
#
# Multiple of 3 and 5.  Write code to
#
#  * Create set \\(A\\) containg natural numbers up to but not including 100 that are multiples of 3
#  * Create set \\(B\\) containg natural numbers up to but not including 100 that are multiples of 5
#  * Output set \\(A\cap B\\)

# %%
# Question 2

# %% [markdown]
# **Question 3**
#
# **Counting primes**. We want to write code to determine how many primes are less than 100 (ans=25). To do this we create a set \\(A\\) of integers greater than one and less than 100. An then remove, using set minus, multiples of 2, multiples of 3, ... . Then we determine the size of the resulting set.
#
# Write code to
#
#  * Create set \\(A\\) containing integers, greater than 1, up to but not including 100
#  * Create set containing positive integers up to but not including 100 that are multiples of 2 and remove this from set \\(A\\).
#  * Repeat for multiples of 3, ... When can you stop ??
#  * Output the final set.

# %%
# Question 3

# %% [markdown]
# ## Relations

# %% [markdown]
# **Question 4**
#
#
# Write code to
#
#  * Create set \\(A\\) containg positive integers up to but not including 100.
#  * Create set \\(B\\) containg positive integers up to but not including 100.
#  * Create a relation \\(R\\) from \\(A\\) to \\(B\\) where \\( (a,b)\in R\\) iff \\(a^2=b\\)

# %%
# Question 4

# %% [markdown]
# ### Visualisation of a Relation on a set using Directed Graph (Digraph)
#
# **Question 5**
#
# After defining relation \\(R\\) in question 4, just run the following code and verify that you agree with the output.

# %%
# Question 5
import networkx as nx
        
G = nx.DiGraph()
G.add_edges_from(R)
nx.draw(G, with_labels=True)
